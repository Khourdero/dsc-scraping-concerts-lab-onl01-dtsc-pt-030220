# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Create a full scraping pipeline that involves traversing over many pages of a website, dealing with errors and storing data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
# Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
# Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
import requests
from bs4 import BeautifulSoup as BS
import pandas as pd
import numpy as np

# %%
def scrape_events(events_page_url):
    #Your code here
    html = requests.get(events_page_url)
    soup = BS(html.content, 'html.parser')
    events = soup.find('div', id='event-listing')
    listings = events.findAll('li')
    rows = []

    for entry in listings:
        date = entry.find('p', class_='date')
        event = entry.find('article', class_='event-item')
        if event:
            event_name = event.find('h1').find('a').text
            venue = event.find('h1').find('span').contents[1].text
            try:
                attending = int(event.find('p', class_='attending').find('span').text)
            except:
                attending = np.nan
            
            rows.append([event_name, venue, new_date, attending])
        elif date:
            new_date = date.text
        else:
            continue
    
    df = pd.DataFrame(rows, columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"])
    
    return df
scrape_events('https://www.residentadvisor.net/events')
# Out:
#                                            Event_Name  \
# 0     Clinic with Sebastian Mullaert (Circle of Live)
# 1          CCVO Thursdays with Kerim Bey & Joe Dismal
# 2       Postponed - Damian Lazarus (Crosstown Rebels)
# 3               [CANCELLED] DJ Koze & Floating Points
# 4                                           Cancelled
# 5   Desert Dream feat. Walker & Royce, Will Clarke...
# 6   Canceled - Om Unit, The Librarian, J:Kenzo by ...
# 7                          [POSTPONED] Coachella 2020
# 8   DUBLAB x Doom Trip present: The Doom Mix IV Re...
# 9                           Rich Medina presents Home
# 10         Family Reunion presents: Golden Vinyl Club
# 11                                SD Union with Break
# 12                                  Lucidity Festival
# 13              [POSTPONED] Monolink with Viken Arman
# 14                                  [POSTPONED] SAMA'
# 15  Incognito presents Freddy K (LA Debut) - Key V...
# 16                         [POSTPONED] Coachella 2020
# 17                               Preceding Thoughts 4
# 18  Essence of Trance 25 Years of RAM with Ciaran ...
# 19     Planet Disco: The Sponges + Take Me To Tequila
# 20                                  Lucidity Festival
# 21  The Polish Ambassador & Friends with The Human...
# 22  [CANCELLED] Official Movement Pre-Party – Cogn...
# 23                             [POSTPONED] Guy Gerber
# 24                         [POSTPONED] Coachella 2020
# 25                                  Lucidity Festival
# 26  Framework x Goldenvoice x Cuttin Headz present...
# 27                                         Disclosure
#
#                                         Venue          Event_Date  \
# 0                             The Sayers Club  Wed, 08 Apr 2020 /
# 1                              Underground SF  Thu, 09 Apr 2020 /
# 2                                Public Works  Thu, 09 Apr 2020 /
# 3                                 1015 Folsom  Fri, 10 Apr 2020 /
# 4                              F8 1192 Folsom  Fri, 10 Apr 2020 /
# 5                                 Equl Estate  Fri, 10 Apr 2020 /
# 6                                Public Works  Fri, 10 Apr 2020 /
# 7                            Empire Polo Club  Fri, 10 Apr 2020 /
# 8                           TBA - Downtown LA  Fri, 10 Apr 2020 /
# 9                                    Resident  Fri, 10 Apr 2020 /
# 10                                   251 Club  Fri, 10 Apr 2020 /
# 11                                       Spin  Fri, 10 Apr 2020 /
# 12                        Live Oak Campground  Fri, 10 Apr 2020 /
# 13                                 The Midway  Fri, 10 Apr 2020 /
# 14                                    Halcyon  Fri, 10 Apr 2020 /
# 15                          TBA - Los Angeles  Sat, 11 Apr 2020 /
# 16                           Empire Polo Club  Sat, 11 Apr 2020 /
# 17                          TBA - Downtown LA  Sat, 11 Apr 2020 /
# 18                           Avalon Hollywood  Sat, 11 Apr 2020 /
# 19                          The Valencia Room  Sat, 11 Apr 2020 /
# 20                        Live Oak Campground  Sat, 11 Apr 2020 /
# 21                               The Fillmore  Sat, 11 Apr 2020 /
# 22                          TBA - Los Angeles  Sat, 11 Apr 2020 /
# 23                                    Halcyon  Sat, 11 Apr 2020 /
# 24                           Empire Polo Club  Sun, 12 Apr 2020 /
# 25                        Live Oak Campground  Sun, 12 Apr 2020 /
# 26                             El Rey Theatre  Tue, 14 Apr 2020 /
# 27  Event Center at San Jose State University  Tue, 14 Apr 2020 /
#
#     Number_of_Attendees
# 0                   7.0
# 1                   1.0
# 2                  22.0
# 3                  37.0
# 4                  22.0
# 5                   2.0
# 6                   2.0
# 7                  23.0
# 8                   2.0
# 9                   1.0
# 10                  1.0
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                 19.0
# 16                 23.0
# 17                  4.0
# 18                  2.0
# 19                  1.0
# 20                  NaN
# 21                  NaN
# 22                  9.0
# 23                  NaN
# 24                 23.0
# 25                  NaN
# 26                 13.0
# 27                  6.0

# %%
events = soup.find('div', id='event-listing')
listings = events.findAll('li')
#find date
listings[0].find('p', class_='date').text
#find event
listings[1].find('article', class_='event-item')
listings[1].find('h1').find('span').contents[1].text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-afbd9ca52718> in <module>
# ----> 1 events = soup.find('div', id='event-listing')
#       2 listings = events.findAll('li')
#       3 #find date
#       4 listings[0].find('p', class_='date').text
#       5 #find event
#
# NameError: name 'soup' is not defined

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    #Your code here
    html = requests.get(url)
    soup = BS(html.content, 'html.parser')
    next_end = soup.find('li', id='liNext2').find('a').attrs['href']
    next_page_url = 'https://www.residentadvisor.net' + next_end
    return next_page_url

next_page('https://www.residentadvisor.net/events/us/california/week/2020-04-15')
# Out:
# 'https://www.residentadvisor.net/events/us/california/week/2020-04-22'

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
#Your code here
df_final = pd.DataFrame(columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"])

dfs_to_group = []

length_of_df = 0

iterations = 0

web_page = 'https://www.residentadvisor.net/events/us/california'

while length_of_df <= 170:
    df_toadd = scrape_events(web_page)
    dfs_to_group.append(df_toadd)
    web_page = next_page(web_page)
    length_of_df += len(df_toadd)
    iterations += 1
    print(iterations, " ", length_of_df)

df_final = pd.concat(dfs_to_group, ignore_index = True)
print('COMPLETE')
# Out:
# 1   28
# 2   54
# 3   73
# 4   85
# 5   94
# 6   110
# 7   116
# 8   121
# 9   127
# 10   135
# 11   139
# 12   146
# 13   146
# 14   148
# 15   149
# 16   153
# 17   155
# 18   155
# 19   155
# 20   155
# 21   156
# 22   156
# 23   157
# 24   158
# 25   159
# 26   161
# 27   165
# 28   166
# 29   167
# 30   168
# 31   170
# 32   171
# COMPLETE

# %%
df_final.sort_values('Number_of_Attendees', ascending = False)
# Out:
#                                           Event_Name  \
# 137                   All Day I Dream of Golden Days
# 136                   All Day I Dream of Golden Days
# 120                             Paradise in the Park
# 117                             Paradise in the Park
# 80   [POSTPONED] Rumors Los Angeles Block Party 2020
# ..                                               ...
# 86            Boshke Beats XX Years Anniversary Tour
# 151                            FNGRS CRSSD Pres: OTR
# 153  Sequence Feat. Gentlemen's Club & Dirty Snatcha
# 168      Cancelled - Mardeleva Live in San Francisco
# 169           Mardeleva Live in San Francisco - Pawa
#
#                          Venue          Event_Date  Number_of_Attendees
# 137           Golden Gate Park  Sun, 21 Jun 2020 /                722.0
# 136           Golden Gate Park  Sat, 20 Jun 2020 /                722.0
# 120            Pershing Square  Sun, 31 May 2020 /                511.0
# 117            Pershing Square  Sat, 30 May 2020 /                511.0
# 80     Gin Ling Way, Chinatown  Sat, 02 May 2020 /                393.0
# ..                         ...                 ...                  ...
# 86                   AC Lounge  Thu, 07 May 2020 /                  NaN
# 151                  Bang Bang  Sat, 25 Jul 2020 /                  NaN
# 153                 DNA Lounge  Thu, 30 Jul 2020 /                  NaN
# 168  906 World Cultural Center  Sat, 07 Nov 2020 /                  NaN
# 169  906 World Cultural Center  Sat, 07 Nov 2020 /                  NaN
#
# [171 rows x 4 columns]

# %%
# Limited to 170 rows due to not enough events to make 1000

# %% [markdown]
# ## Summary
#
# Congratulations! In this lab, you successfully developed a pipeline to scrape a website for concert event information!
